# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.feature_extraction import DictVectorizer

#读取数据
data = pd.read_csv("kaggle_bike_competition_train.csv", header=0, error_bad_lines=True)

#数据清洗
temp = pd.DatetimeIndex(data.datetime)
data['date'] = temp.date
data['time'] = temp.time
data['hour'] = temp.hour
data['daysofweek'] = temp.dayofweek
data['days'] = (data.date - data.date[0]).astype('timedelta64[D]')
data['sat'] = 0
data['sun'] = 0
data.sat[data.daysofweek == 5] = 1
data.sun[data.daysofweek == 6] = 1
datarel = data.drop(['datetime', 'count', 'date', 'time', 'daysofweek'], axis=1)
datarel.head()

#数据归一化和离散化
#连续值的属性放入一个dict中
f1 = ['temp', 'atemp', 'humidity', 'windspeed', 'days', 'hour']
d1 = datarel[f1].fillna('NA')
y1 = d1.T.to_dict().values()
#离散值放到另外一个字典中
f2 = ['season','holiday','workingday','weather','sat', 'sun']
d2 = datarel[f2].fillna('NA')
y2 = d2.T.to_dict().values()

#字典向量化
vec = DictVectorizer(sparse=False)
X1 = vec.fit_transform(y1)
X2 = vec.fit_transform(y2)

#将连续数值归一化
s = preprocessing.StandardScaler()
s.fit(X1)
X1 = s.transform(X1)
#将离散数值编码化
e = preprocessing.OneHotEncoder()
e.fit(X2)
X2 = e.transform(X2).toarray()

#合并离散数据和连续数据
X = np.c_[X1, X2]

#将结果集进行浮点化
y_c = data['registered'].values.astype('float64')
y_r = data['casual'].values.astype('float64')
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.feature_extraction import DictVectorizer
data = pd.read_csv("kaggle_bike_competition_train.csv", header=0, error_bad_lines=True)
data.head()
# Out:
#         datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011/1/1 0:00       1        0           0        1  9.84  14.395
# 1  2011/1/1 1:00       1        0           0        1  9.02  13.635
# 2  2011/1/1 2:00       1        0           0        1  9.02  13.635
# 3  2011/1/1 3:00       1        0           0        1  9.84  14.395
# 4  2011/1/1 4:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
data = pd.read_csv("kaggle_bike_competition_train.csv", header=0, error_bad_lines=True)
temp = pd.DatetimeIndex(data.datetime)
data['date'] = temp.date
data['time'] = temp.time
data['hour'] = temp.hour
data['minute'] = temp.minute
data['second'] = temp.second
data['dayofweek'] = temp.dayofweek
data['days'] = (data.date - data.date[0]).astype('timedelta64[D]')
data['sat'] = 0
data['sun'] = 0
data.sat[data.dayofweek == 5] = 1
data.sun[data.dayofweek == 6] = 1

f1 = ['temp', 'atemp', 'humidity', 'windspeed', 'days', 'hour']
d1 = data[f1].fillna('NA')
x1 = d1.T.to_dict().values()

f2 = ['season', 'holiday', 'workingday', 'weather', 'sat', 'sun']
d2 = data[f2].fillna('NA')
x2 = d2.T.to_dict().values()

vec = DictVectorizer(sparse=False)
X1 = vec.fit_transform(x1)
X2 = vec.fit_transform(x2)

s = preprocessing.StandardScaler()
s.fit(X1)
X1 = s.fit_transform(X1)

e = preprocessing.OneHotEncoder()
e.fit(X2)
X2 = e.fit_transform(X2).toarray()

X = np.c_[X1, X2]
y1 = data['casual'].values.astype('float64') 
y2 = data['registered'].values.astype('float64')
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
y1 * y2
# Out:
# array([   39.,   256.,   135., ...,   656.,  1404.,   336.])

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.feature_extraction import DictVectorizer

# %%
data = pd.read_csv("kaggle_bike_competition_train.csv", header=0, error_bad_lines=True)
data.head()
# Out:
#         datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011/1/1 0:00       1        0           0        1  9.84  14.395
# 1  2011/1/1 1:00       1        0           0        1  9.02  13.635
# 2  2011/1/1 2:00       1        0           0        1  9.02  13.635
# 3  2011/1/1 3:00       1        0           0        1  9.84  14.395
# 4  2011/1/1 4:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
temp = pd.DatetimeIndex(data['datetime'])
data['date'] = temp.date
data['time'] = temp.time
data['hour'] = temp.hour
data['minute'] = temp.minute
data['second'] = temp.second
data['dayofweek'] = temp.dayofweek
data['days'] = (data.date - data.date[0]).astype('timedelta64[D]')
data['sat'] = 0
data['sun'] = 0
data.sat[data.dayofweek == 5] = 1
data.sun[data.dayofweek == 6] = 1

f1 = ['temp', 'atemp', 'humidity', 'windspeed', 'days', 'hour']
d1 = data[f1]
x1 = d1.T.to_dict().values()
      
f2 = ['season', 'holiday', 'workingday', 'weather', 'sat', 'sun']
d2 = data[f2]
x2 = d2.T.to_dict().values()
      
vec = DictVectorizer(sparse=False)
X1 = vec.fit_transform(x1)
X2 = vec.fit_transform(x2)
      
s = preprocessing.StandardScaler()
s.fit(X1)
X1 = s.fit_transform(X1)

e = preprocessing.OneHotEncoder()
e.fit(X2)
X2 = e.fit_transform(X2).toarray()
      
X = np.c_[X1, X2]
y1 = data['casual'].values.astype('float64')
y2 = data['registered'].values.astype('float64')
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
X
# Out:
# array([[-1.09273697, -1.70912256, -1.66894356, ...,  0.        ,
#          1.        ,  0.        ],
#        [-1.18242083, -1.70912256, -1.52434128, ...,  0.        ,
#          1.        ,  0.        ],
#        [-1.18242083, -1.70912256, -1.379739  , ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [-0.91395927,  1.70183906,  1.36770431, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.73518157,  1.70183906,  1.51230659, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.82486544,  1.70183906,  1.65690887, ...,  0.        ,
#          0.        ,  1.        ]])
